# %%
# Importing Libraries
import pandas as pd

import seaborn as sns

import datetime

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("DataSet/car data.csv")

# %%
data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
data.shape
# Out:
# (301, 9)

# %%
print("Fuel_Type", data["Fuel_Type"].unique())
print("="*50)
print("Seller_Type", data["Seller_Type"].unique())
print("="*50)
print("Transmission", data["Transmission"].unique())
print("="*50)
print("Owner", data["Owner"].unique())
print("="*50)
print("Car_Name", data["Car_Name"].unique())
# Out:
# Fuel_Type ['Petrol' 'Diesel' 'CNG']
# ...
# Seller_Type ['Dealer' 'Individual']
# ...
# Transmission ['Manual' 'Automatic']
# ...
# Owner [0 1 3]
# ...
# Car_Name ['ritz' 'sx4' 'ciaz' 'wagon r' 'swift' 'vitara brezza' 's cross'
#  'alto 800' 'ertiga' 'dzire' 'alto k10' 'ignis' '800' 'baleno' 'omni'
#  'fortuner' 'innova' 'corolla altis' 'etios cross' 'etios g' 'etios liva'
#  'corolla' 'etios gd' 'camry' 'land cruiser' 'Royal Enfield Thunder 500'
#  'UM Renegade Mojave' 'KTM RC200' 'Bajaj Dominar 400'
#  'Royal Enfield Classic 350' 'KTM RC390' 'Hyosung GT250R'
#  'Royal Enfield Thunder 350' 'KTM 390 Duke ' 'Mahindra Mojo XT300'
#  'Bajaj Pulsar RS200' 'Royal Enfield Bullet 350'
#  'Royal Enfield Classic 500' 'Bajaj Avenger 220' 'Bajaj Avenger 150'
#  'Honda CB Hornet 160R' 'Yamaha FZ S V 2.0' 'Yamaha FZ 16'
#  'TVS Apache RTR 160' 'Bajaj Pulsar 150' 'Honda CBR 150' 'Hero Extreme'
#  'Bajaj Avenger 220 dtsi' 'Bajaj Avenger 150 street' 'Yamaha FZ  v 2.0'
# ...

# %% [markdown]
# ### Missing values and Data Describe
# ================================================================================================================

# %%
data.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
data.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %% [markdown]
# ##### Adding required columns and Removing unnecessary columns
# Remove unnecessary column ("Car_Name"),
# Add column ("Current_Year") with value 2021,
# Add column ("Num_Years") with Current_Year - Old_Year,
# Drop columns ("Year", "Current_Year")

# %%
data = data[['Year', 'Selling_Price', 'Present_Price', 'Kms_Driven', 'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner']]
data
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner
# 0         Manual      0
# 1         Manual      0
# ...

# %%
data["Current_Year"]=2021
data
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  Current_Year
# 0         Manual      0          2021
# ...

# %%
data["Num_Years"] = data["Current_Year"] - data["Year"]
data
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  Current_Year  Num_Years
# ...

# %%
data.drop(["Year", "Current_Year"], axis=1, inplace=True)
data.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0           3.35           5.59       27000    Petrol      Dealer
# 1           4.75           9.54       43000    Diesel      Dealer
# 2           7.25           9.85        6900    Petrol      Dealer
# 3           2.85           4.15        5200    Petrol      Dealer
# 4           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Num_Years
# 0       Manual      0          7
# 1       Manual      0          8
# 2       Manual      0          4
# 3       Manual      0         10
# 4       Manual      0          7

# %% [markdown]
# ### Converting Categorical to Numerical
# ================================================================================================================

# %%
data = pd.get_dummies(data, drop_first=True)
data
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Owner  Num_Years  \
# 0             3.35           5.59       27000      0          7
# 1             4.75           9.54       43000      0          8
# 2             7.25           9.85        6900      0          4
# 3             2.85           4.15        5200      0         10
# 4             4.60           6.87       42450      0          7
# ..             ...            ...         ...    ...        ...
# 296           9.50          11.60       33988      0          5
# 297           4.00           5.90       60000      0          6
# 298           3.35          11.00       87934      0         12
# 299          11.50          12.50        9000      0          4
# 300           5.30           5.90        5464      0          5
#
#      Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0                   0                 1                       0
# 1                   1                 0                       0
# ...

# %% [markdown]
# ### Correlation
# ==================================================================================================================
# Data representation with function "corr()".
# Visual representation with functions in library seaborn

# %%
data.corr()
# Out:
#                         Selling_Price  Present_Price  Kms_Driven     Owner  \
# Selling_Price                1.000000       0.878983    0.029187 -0.088344
# Present_Price                0.878983       1.000000    0.203647  0.008057
# Kms_Driven                   0.029187       0.203647    1.000000  0.089216
# Owner                       -0.088344       0.008057    0.089216  1.000000
# Num_Years                   -0.236141       0.047584    0.524342  0.182104
# Fuel_Type_Diesel             0.552339       0.473306    0.172515 -0.053469
# Fuel_Type_Petrol            -0.540571      -0.465244   -0.172874  0.055687
# Seller_Type_Individual      -0.550724      -0.512030   -0.101419  0.124269
# Transmission_Manual         -0.367128      -0.348715   -0.162510 -0.050316
#
#                         Num_Years  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# Selling_Price           -0.236141          0.552339         -0.540571
# Present_Price            0.047584          0.473306         -0.465244
# ...

# %%
import seaborn as sns

# %%
startTime = datetime.datetime.now()
sns.pairplot(data)
endTime = datetime.datetime.now()

# %%
print("Time taken to run pairplot : ", endTime - startTime)
# Out:
# Time taken to run pairplot :  0:00:05.489878

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
list(data.corr().index)
# Out:
# ['Selling_Price',
#  'Present_Price',
#  'Kms_Driven',
#  'Owner',
#  'Num_Years',
#  'Fuel_Type_Diesel',
#  'Fuel_Type_Petrol',
#  'Seller_Type_Individual',
#  'Transmission_Manual']

# %%
corrMat = data.corr()
topCorrFeatures = corrMat.index
plt.figure(figsize=(10,10))
g = sns.heatmap(data[topCorrFeatures].corr(), annot=True, cmap="coolwarm", square=True)

# %% [markdown]
# ### Splitting dataset into Independent and Dependent Features
# ========================================================================================================================

# %%
X = data[['Present_Price','Kms_Driven', 'Owner', 'Num_Years', 'Fuel_Type_Diesel', 'Fuel_Type_Petrol', 'Seller_Type_Individual', 'Transmission_Manual']]
y = data["Selling_Price"]

# %% [markdown]
# ### Importent Features
# =======================================================================================================================
# Finding what are the importent features in the dataset

# %%
### Feature Importance

from sklearn.ensemble import ExtraTreesRegressor
import matplotlib.pyplot as plt
ETR = ExtraTreesRegressor()
ETR.fit(X, y)
# Out:
# ExtraTreesRegressor()

# %%
print(ETR.feature_importances_)

# %%
#plot graph of feature importances for better visualization
feat_importances = pd.Series(ETR.feature_importances_, index=X.columns)
feat_importances.nlargest(5).plot(kind='barh')
plt.show()

# %% [markdown]
# # Concepts

# %%
import time
print(time.ctime()) # 'Mon Oct 18 13:35:29 2010'
print(time.strftime('%X %x %Z'))
# Out:
# Tue Sep 14 19:16:38 2021
# 19:16:38 09/14/21 India Standard Time
